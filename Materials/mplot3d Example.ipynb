# %% [markdown]
# # mplot3d tutorial

# %% [markdown]
# ### Import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
from sklearn.decomposition import PCA
# %matplotlib notebook
# %matplotlib notebook

# %% [markdown]
# ### Create a simple plot

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d') # figure 1 by 1 by 1
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Spawn some data

# %%
X = np.random.random((10, 3))
X
# Out:
# array([[0.35833158, 0.54892098, 0.01012202],
#        [0.96443351, 0.2577539 , 0.76774036],
#        [0.60242929, 0.77202947, 0.90375136],
#        [0.43951543, 0.96850052, 0.89897975],
#        [0.0232071 , 0.49083711, 0.07805046],
#        [0.47526793, 0.62053453, 0.60998768],
#        [0.12794649, 0.81650255, 0.72680439],
#        [0.07377485, 0.88718834, 0.53177068],
#        [0.44927616, 0.91418504, 0.4318125 ],
#        [0.87300185, 0.61395417, 0.98882137]])

# %% [markdown]
# ### Plot the data

# %% [markdown]
# PCA will convert np.array into acceptable data object

# %%
pca = PCA(n_components=3)

# %% [markdown]
# Load the data

# %%
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=3, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %% [markdown]
# Transform the data

# %%
X_pca = pca.transform(X)

# %% [markdown]
# Plot the data

# %%
ax.scatter3D(X_pca[:, 0], X_pca[:, 1], X_pca[:,2])

# %%
fig.show()

# %% [markdown]
# ### The output will appear in the upper plot
